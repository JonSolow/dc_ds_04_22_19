# %%
# create your first simulation
### 1. Open the notebook about python fundmentals 
### 2. Add records to the dictionary until you have 24 names 
### 3. loop through the dictionary in pairs (pick two records at a time)
### 4. Use numpy random to throw a coin (virtual coin)
### 5. if heads delete first record, else delete second record 
### 6. continue till there is one winner 
### 7. print winner's name 
### 8. execute from terminal

# %%
# create your first simulation
### 1. Open the notebook about python fundmentals

# %%
### 2. Add records to the dictionary until you have 24 names

# %%
import numpy as np

# %%
names_as_text = """Solange Mance
Candra Roberie
Marielle Truman
Sebastian Troutman
Gaston Westman
Harold Takacs
Shavon Karr
Kymberly Quintanar
Ciara Washam
Marin Crittendon
Eleonora Henningsen
Ethel Thiele
Linnea Tweed
Maritza Moates
Rafaela Hester
Robyn Keeter
Gemma Maravilla
Stephine Reiner
Lynwood Cordeiro
Earnest Endres
Myron Issa
Niki Mealing
Kaylene Accardo
Haywood Mcmann
Huey Wilkerson
Magnolia Loveall
Joesph Southworth
King Cabaniss
Eugenie Perea
Dorie Maziarz"""

names_as_list = names_as_text.split('\n')
names_as_list

names_as_dict = {}

for names in names_as_list:
    if len(names_as_dict) < 24:
        names_as_dict.update({names: np.random.randint(25)})

names_as_dict
# Out:
# {'Solange Mance': 24,
#  'Candra Roberie': 6,
#  'Marielle Truman': 6,
#  'Sebastian Troutman': 0,
#  'Gaston Westman': 7,
#  'Harold Takacs': 19,
#  'Shavon Karr': 5,
#  'Kymberly Quintanar': 17,
#  'Ciara Washam': 23,
#  'Marin Crittendon': 0,
#  'Eleonora Henningsen': 18,
#  'Ethel Thiele': 4,
#  'Linnea Tweed': 19,
#  'Maritza Moates': 18,
#  'Rafaela Hester': 8,
#  'Robyn Keeter': 11,
#  'Gemma Maravilla': 8,
#  'Stephine Reiner': 21,
#  'Lynwood Cordeiro': 7,
#  'Earnest Endres': 12,
#  'Myron Issa': 0,
#  'Niki Mealing': 21,
#  'Kaylene Accardo': 1,
#  'Haywood Mcmann': 2}

# %%
# regenerating the list of names, which we only already had because of how we created the dictionary

names_as_list = []
for k, v in names_as_dict.items():
    names_as_list.append(k)

# initial round number
round_no = 1

# keep looping until 1 team remains
while len(names_as_dict) > 1:
    # print the current round number and number of teams
    print('Round Number: ', round_no)
    print(len(names_as_dict), ' teams remain \n')
    # keep track of how many have been removed in this round for adjusting indexing
    removed = 0
    # loop for the current number of names in this round
    for i in range(len(names_as_dict)):
        # first condition will make us skip over every other item
        # second condition handles cases where there are an odd number of teams remaining in that round
        if (i % 2 == 0) and (i+1-removed) < len(names_as_dict):
            # flip coin
            coinflip = np.random.randint(0, 2)
            # print the current matchup
            # note index is i - removed = first person
            print(names_as_list[i - removed], ' vs ',
                  names_as_list[i+1 - removed])
            print(['heads', 'tails'][1-coinflip])
            # print the winner
            print(names_as_list[i - removed+(1-coinflip)], ' wins', '\n')
            # remove the loser from dictionary and list
            names_as_dict.pop(names_as_list[i - removed+coinflip])
            names_as_list.pop(i - removed+coinflip)
            # keep track of number removed
            removed += 1
    # advance round
    round_no += 1
# Out:
# Round Number:  1
# 24  teams remain
#
# Solange Mance  vs  Candra Roberie
# tails
# Candra Roberie  wins
#
# Marielle Truman  vs  Sebastian Troutman
# heads
# Marielle Truman  wins
#
# Gaston Westman  vs  Harold Takacs
# tails
# Harold Takacs  wins
#
# Shavon Karr  vs  Kymberly Quintanar
# heads
# Shavon Karr  wins
#
# Ciara Washam  vs  Marin Crittendon
# heads
# Ciara Washam  wins
#
# Eleonora Henningsen  vs  Ethel Thiele
# tails
# Ethel Thiele  wins
#
# Linnea Tweed  vs  Maritza Moates
# heads
# Linnea Tweed  wins
#
# Rafaela Hester  vs  Robyn Keeter
# tails
# Robyn Keeter  wins
#
# Gemma Maravilla  vs  Stephine Reiner
# heads
# Gemma Maravilla  wins
#
# Lynwood Cordeiro  vs  Earnest Endres
# heads
# Lynwood Cordeiro  wins
#
# Myron Issa  vs  Niki Mealing
# heads
# Myron Issa  wins
#
# Kaylene Accardo  vs  Haywood Mcmann
# tails
# Haywood Mcmann  wins
#
# Round Number:  2
# 12  teams remain
#
# Candra Roberie  vs  Marielle Truman
# heads
# Candra Roberie  wins
#
# Harold Takacs  vs  Shavon Karr
# tails
# Shavon Karr  wins
#
# Ciara Washam  vs  Ethel Thiele
# heads
# Ciara Washam  wins
#
# Linnea Tweed  vs  Robyn Keeter
# heads
# Linnea Tweed  wins
#
# Gemma Maravilla  vs  Lynwood Cordeiro
# tails
# Lynwood Cordeiro  wins
#
# Myron Issa  vs  Haywood Mcmann
# heads
# Myron Issa  wins
#
# Round Number:  3
# 6  teams remain
#
# Candra Roberie  vs  Shavon Karr
# heads
# Candra Roberie  wins
#
# Ciara Washam  vs  Linnea Tweed
# tails
# Linnea Tweed  wins
#
# Lynwood Cordeiro  vs  Myron Issa
# tails
# Myron Issa  wins
#
# Round Number:  4
# 3  teams remain
#
# Candra Roberie  vs  Linnea Tweed
# tails
# Linnea Tweed  wins
#
# Round Number:  5
# 2  teams remain
#
# Linnea Tweed  vs  Myron Issa
# tails
# Myron Issa  wins
