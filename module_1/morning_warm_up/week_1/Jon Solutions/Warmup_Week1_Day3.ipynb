# %% [markdown]
# #  For loops and alternatives
#
# Given an array of integers, return the index of of the target number - try doing it with a for loop. Notice that the target number can repeat several times.
#
#
# ### Example:
#
# Given nums = [2, 9, 11, 15], target = 9,
#
# Because nums[1] = 9
#
# return [1].

# %%
GivenList = [2,9,11,15]
target = 9

for i in range(len(GivenList)):
    if GivenList[i]==target:
        print(i)
# Out:
# 1

# %% [markdown]
# # [optional I] - solve with for loops
#  You have an array of integers, return indices of the two numbers such that they add  to a target.
# Assume that each input would have exactly one solution, and you may not use the same element twice.
# Given nums = [2, 7, 11, 15], target = 9,
#
# ### Example
# Because nums[0] + nums[1] = 2 + 7 = 9,
# return [0, 1].

# %%
GivenList = [2,9,11,15]
target = 20
bVar = False

for i in range(len(GivenList)):
    if bVar: break
    for j in range(len(GivenList)):
        if i!=j and GivenList[i]+GivenList[j]==target:
            print([i,j])            
            bVar = True
            break
# Out:
# [1, 2]

# %% [markdown]
#  # [optional II] - solve the same with only one loop and a dictionary

# %%
GivenList = [2,9,11,15]
target = 20
bVar = False

for
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ce0e8fee4e3b> in <module>()
#       4
#       5 for i,j in zip(GivenList,GivenList):
# ----> 6     if i.index!=j.index and i+j==target:
#       7         print([i,j])
#       8         bVar = True
#
# AttributeError: 'int' object has no attribute 'index'
