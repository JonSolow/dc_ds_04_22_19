# %% [markdown]
# # APIs and Python

# %% [markdown]
# ## The Many Use Cases for APIs
# APIs can actually be used for many things - not just for retrieving information. Twilio has an API that allows you to write a script to call their API to send text messages to people. GitHub has an API for creating new repositories. Many services have an API allowing a computer to automate a task that a person might otherwise have to do through a website - whether uploading a photo to Flickr, searching for a company name in a state database or getting a list of garbage collection times for a municipality.

# %% [markdown]
# ### _Learning Goals:_<br/>
#   - Identify and discuss APIs
#   - Discuss and explain different request (GET, POST, PUT, DELETE) and CRUD operations
#   - Explore the attributes of a response object
#   - Check the status of a request and interpret status codes
#   - Access data from an API using the requests library
#   - Create a pandas dataframe from the data returned from an API and visualize the data
#   - If time, target an API of their own!!!

# %% [markdown]
# ## Limitations of APIs
# When working with APIs, there are some limitations you have to be aware of - especially relating to scope and scale.

# %% [markdown]
# * **Scope** - Just because a company has an API and has information, it doesn't mean you can get all of the information through their API.

# %% [markdown]
# * **Scale** - Some APIs are provided for free as a public service. Others you have to pay for, or allow you to perform activities (like sending a text message) that you pay for. Make sure that you know what the rate limits are and that your use case isn't going to need more API calls than you will be able to make.

# %% [markdown]
# Let's take a look at the `requests` library and it's uses.

# %% [markdown]
# ### "Requests is the only Non-GMO HTTP library for Python, safe for human consumption."
#
# ![img-req](requests-pic.jpeg)
#
# Straight from the `requests` [documentation](https://pypi.org/project/requests/)

# %% [markdown]
# ![nongmao](requests_med.png)
#
# "Requests allows you to send organic, grass-fed HTTP/1.1 requests, without the need for manual labor. "<br>
# [More requests documentation](https://2.python-requests.org//en/v0.10.6/api/)

# %% [markdown]
# ### Let's get started!

# %%
import requests

# %%
#!pip install requests

# %% [markdown]
# ### Types of requests
#
# We will mostly use GET, but there are other options
#
# Let's say you are looking at an API for a car rental company like Hertz, or maybe even Zipcar.
#
# The following different requests will generate these different responses.
#
# |Request        | Result        |
# |-------------|-------------|
# |GET /stores/   | User sees the list of stores|
# |GET /rentals/  | User sees the history of car rentals|
# |POST /rentals/ | User rents a car|
# |PUT /rentals/{id}/| User changes destination store|
# |DELETE /rentals/{id}/| User cancels the active car rental|

# %%
rental_json = [{
    "id": 1,
    "name": "John St",
    "location": [29, 95],
    "available_cars_quantity": 10
},
{
    "id": 2,
    "name": "Scott St.",
    "location": [29.5, 95.7],
    "available_cars_quantity": 2
}]

# %%
#create a post request from https://httpbin.org/post and view it in json format

r = requests.post('https://httpbin.org/post', data=rental_json[1]) #put url and data = {'key':'value'} format here in the bananas!
r.json()
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'available_cars_quantity': '2',
#   'id': '2',
#   'location': ['29.5', '95.7'],
#   'name': 'Scott St.'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '73',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '65.207.79.74, 65.207.79.74',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ### Request Class and Attributes

# %%
#create a GET request from https://api.github.com/events and view it in json format

r = requests.get('https://api.github.com/events') #put url here in the bananas!
type(r)
# Out:
# requests.models.Response

# %% [markdown]
# Let's check the `attributes` of a `Response` object. <br>
# https://2.python-requests.org//en/v0.10.6/api/
#
# Some key attributes:
#
# - url
# - text
# - status_code
# - headers
# - error

# %%
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Wed, 15 May 2019 18:47:15 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '403 Forbidden', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1557946825', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': '8F80:3970:69C115:D49E21:5CDC5EB3'}

# %% [markdown]
# ### Checking out the status of your request

# %%
#get the status of your post request
r.status_code
# Out:
# 403

# %% [markdown]
# #### Types of status codes
# 1xx - Informational responses
#
# 2xx - Success
# - 200 OK
# - 201 Created
# - 204 No Content
#
# 3xx - Redirection
#
# - 301 Moved Permanently (permanent URL redirection)
# - 304 Not Modified (A conditional GET or HEAD request has been received and would have resulted in a 200 OK response if it were not for the fact that the condition evaluated to false.)

# %% [markdown]
# 4xx - Client errors
#
# - 400 Bad Request
# - 401 Unauthorized
# - 403 Forbidden
# - 404 Not Found
#
# 5xx - Server errors
#
# - 500 Internal Server Error

# %% [markdown]
# https://http.cat

# %%
#get status code for a "broken" link

r = requests.get('https://api.github.com/fake-ending')
r.status_code
# Out:
# 403

# %% [markdown]
# Can also explictly ask for the returned format to be json as a method.

# %%
r.json()
# Out:
# {'message': "API rate limit exceeded for 65.207.79.74. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)",
#  'documentation_url': 'https://developer.github.com/v3/#rate-limiting'}

# %% [markdown]
# #### A note on errors and exceptions with the Requests library
#
# There are a number of exceptions and error codes you need to be familiar with when using the Requests library in Python.
#
# - The Requests library will raise a ConnectionError exception if there is a network problem like a DNS failure, or refused connection.
# - These are rare, but with invalid HTTP responses, Requests will also raise an HTTPError exception.
# - A Timeout exception will be raised if a request times out.
# - If and when a request exceeds the preconfigured number of maximum redirections, then a TooManyRedirects exception will be raised

# %% [markdown]
# Now that we know a bit more about APIs and how to interact with them in python, let's actually investigate an API from scratch.
#
# To start, go over to the API documentation at:
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
#
# <img src="311_api_docs.png">

# %% [markdown]
# ## Make an initial API call to retrieve 311 complaints from a neighborhood or zip code of your choice in New York City.

# %% [markdown]
# ### Using Requests

# %%
import requests
import pandas as pd

zip_code = '11004'

# can't figure out date ranges at the moment...
start_date = '2018-01-01T12:00:00'
end_date = '2018-02-01T12:00:00'

# create pull request based on parameters
# https://data.cityofnewyork.us/Social-Services/311-Service-Reque`sts-from-2010-to-Present/erm2-nwe9 click API

url = "https://data.cityofnewyork.us/resource/fhrw-4uyv.json?incident_zip={}".format(zip_code)

# do the pull
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
else:
    print('Hit an error.')

# %% [markdown]
# ## Briefly Explore the Structure of the Response You Received.

# %% [markdown]
# ### Let's look at the output of our API call to NYC 311

# %%
print(type(data))
# Out:
# <class 'list'>

# %%
len(data)
# Out:
# 1000

# %%
df_311 = pd.DataFrame.from_dict(data)
df_311
# Out:
#      address_type agency                             agency_name         bbl  \
# 0    INTERSECTION    DOT            Department of Transportation         NaN
# 1         ADDRESS    DPR      Department of Parks and Recreation  4087710037
# 2         ADDRESS    DPR      Department of Parks and Recreation  4087340057
# 3    INTERSECTION    DOT            Department of Transportation         NaN
# 4         ADDRESS    DPR      Department of Parks and Recreation  4086840051
# 5         ADDRESS   DSNY                Department of Sanitation  4087420125
# 6    INTERSECTION    DOT            Department of Transportation         NaN
# 7    INTERSECTION    DOT            Department of Transportation         NaN
# 8         ADDRESS   DSNY                Department of Sanitation  4087400201
# 9         ADDRESS    DEP  Department of Environmental Protection  4087400256
# 10        ADDRESS    DEP  Department of Environmental Protection  4087400220
# 11        ADDRESS    DEP  Department of Environmental Protection  4087410124
# 12        ADDRESS    DEP  Department of Environmental Protection  4087230070
# 13        ADDRESS    DEP  Department of Environmental Protection  4087410105
# 14        ADDRESS    DEP  Department of Environmental Protection  4087410120
# 15        ADDRESS    DEP  Department of Environmental Protection  4087390020
# 16        ADDRESS   DSNY                Department of Sanitation  4087790033
# 17   INTERSECTION    DOT            Department of Transportation         NaN
# 18        ADDRESS    DEP  Department of Environmental Protection  4087240216
# 19   INTERSECTION    DOT            Department of Transportation         NaN
# 20   INTERSECTION    DOT            Department of Transportation         NaN
# 21   INTERSECTION    DOT            Department of Transportation         NaN
# 22   INTERSECTION    DOT            Department of Transportation         NaN
# 23   INTERSECTION    DOT            Department of Transportation         NaN
# 24   INTERSECTION    DOT            Department of Transportation         NaN
# 25   INTERSECTION    DOT            Department of Transportation         NaN
# 26   INTERSECTION    DOT            Department of Transportation         NaN
# 27        ADDRESS    DOF                 Personal Exemption Unit  4087730019
# 28   INTERSECTION    DOT            Department of Transportation         NaN
# 29        ADDRESS    DOF                 Personal Exemption Unit  4084470001
# ..            ...    ...                                     ...         ...
# 970       ADDRESS    DOF                 Personal Exemption Unit  4086930026
# 971       ADDRESS    DOF                    Property Exec Office  4087770033
# 972       ADDRESS    DOF                    Property Exec Office  4087000020
# 973       ADDRESS    DOF                 Personal Exemption Unit  4087100053
# 974       ADDRESS    DOF                 Personal Exemption Unit  4086730012
# 975       ADDRESS    DOF                 Personal Exemption Unit  4087430102
# 976       ADDRESS    DOF                 Personal Exemption Unit  4087100053
# 977       ADDRESS    DOF                 Personal Exemption Unit  4087150057
# 978       ADDRESS    DOF               Commercial Exemption Unit  4086790073
# 979       ADDRESS   DFTA                Department for the Aging  4087750043
# 980       ADDRESS    DOF                 Personal Exemption Unit  4085350002
# 981       ADDRESS    DOF                 Personal Exemption Unit  4085170002
# 982       ADDRESS    DOF                     Correspondence Unit  4087000029
# 983       ADDRESS    DOF                     Correspondence Unit  4087350053
# 984       ADDRESS   DFTA                Department for the Aging  4086990059
# 985       ADDRESS    DOF                      Condo or CoOp Unit  4085130020
# 986       ADDRESS    DOF                    Property Exec Office  4087000048
# 987       ADDRESS    DOF                     Correspondence Unit  4087560011
# 988       ADDRESS    DOF                 Personal Exemption Unit  4087100015
# 989       ADDRESS    DOF                 Refunds and Adjustments  4087510047
# 990       ADDRESS    DOF                            Land Records  4087820063
# 991       ADDRESS    DOF                 Personal Exemption Unit  4087590152
# 992       ADDRESS    DOF                     Correspondence Unit  4087350053
# 993       ADDRESS    DOF                     Correspondence Unit  4086820003
# 994       ADDRESS    DOF                    Property Exec Office  4086820003
# 995       ADDRESS   DFTA                Department for the Aging  4087180017
# 996       ADDRESS    DOF                 Personal Exemption Unit  4084410001
# 997       ADDRESS    DOF                 Personal Exemption Unit  4084420001
# 998       ADDRESS    DOF                 Personal Exemption Unit         NaN
# 999       ADDRESS    DOF                 Personal Exemption Unit  4085350002
#
#     borough       city              closed_date community_board  \
# 0    QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 1    QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 2    QUEENS  GLEN OAKS  2019-05-13T16:00:18.000       13 QUEENS
# 3    QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 4    QUEENS  GLEN OAKS  2019-05-13T17:00:38.000       13 QUEENS
# 5    QUEENS  Glen Oaks  2019-05-14T00:00:00.000       13 QUEENS
# 6    QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 7    QUEENS  Glen Oaks  2019-05-10T11:36:00.000       13 QUEENS
# 8    QUEENS  Glen Oaks  2019-05-14T00:00:00.000       13 QUEENS
# 9    QUEENS  Glen Oaks  2019-05-12T02:05:00.000       13 QUEENS
# 10   QUEENS  Glen Oaks  2019-05-09T17:45:00.000       13 QUEENS
# 11   QUEENS  Glen Oaks  2019-05-13T14:28:00.000       13 QUEENS
# 12   QUEENS  Glen Oaks  2019-05-13T14:31:00.000       13 QUEENS
# 13   QUEENS  Glen Oaks  2019-05-13T14:29:00.000       13 QUEENS
# 14   QUEENS  Glen Oaks  2019-05-13T14:28:00.000       13 QUEENS
# 15   QUEENS  Glen Oaks  2019-05-12T01:30:00.000       13 QUEENS
# 16   QUEENS  Glen Oaks  2019-05-14T00:00:00.000       13 QUEENS
# 17   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 18   QUEENS  Glen Oaks  2019-05-13T14:30:00.000       13 QUEENS
# 19   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 20   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 21   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 22   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 23   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 24   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 25   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 26   QUEENS  GLEN OAKS                      NaN       13 QUEENS
# 27   QUEENS  GLEN OAKS  2019-05-13T17:40:41.000       13 QUEENS
# 28   QUEENS  GLEN OAKS  2019-05-13T12:10:02.000       13 QUEENS
# 29   QUEENS  GLEN OAKS  2019-05-13T09:37:16.000       13 QUEENS
# ..      ...        ...                      ...             ...
# 970  QUEENS  GLEN OAKS  2013-11-12T14:49:46.000       13 QUEENS
# 971  QUEENS  GLEN OAKS  2013-10-31T11:39:34.000       13 QUEENS
# 972  QUEENS  GLEN OAKS  2013-11-06T12:05:40.000       13 QUEENS
# 973  QUEENS  GLEN OAKS  2013-11-08T12:20:26.000       13 QUEENS
# 14            ...                  QUEENS        Unspecified
# 15            ...                  QUEENS        Unspecified
# 16            ...                  QUEENS        Unspecified
# 17            ...                  QUEENS        Unspecified
# 18            ...                  QUEENS        Unspecified
# 19            ...                  QUEENS        Unspecified
# 20            ...                  QUEENS        Unspecified
# 21            ...                  QUEENS        Unspecified
# 22            ...                  QUEENS        Unspecified
# 23            ...                  QUEENS        Unspecified
# 24            ...                  QUEENS        Unspecified
# 25            ...                  QUEENS        Unspecified
# 26            ...                  QUEENS        Unspecified
# 27            ...                  QUEENS        Unspecified
# 28            ...                  QUEENS        Unspecified
# 29            ...                  QUEENS        Unspecified
# ..            ...                     ...                ...
# 970           ...                  QUEENS        Unspecified
# 971           ...                  QUEENS        Unspecified
# 972           ...                  QUEENS        Unspecified
# 973           ...                  QUEENS        Unspecified
# 974           ...                  QUEENS        Unspecified
# 975           ...                  QUEENS        Unspecified
# 976           ...                  QUEENS        Unspecified
# 977           ...                  QUEENS        Unspecified
# 978           ...                  QUEENS        Unspecified
# 979           ...                  QUEENS        Unspecified
# 980           ...                  QUEENS        Unspecified
# 981           ...                  QUEENS        Unspecified
# 982           ...                  QUEENS        Unspecified
# 983           ...                  QUEENS        Unspecified
# 984           ...                  QUEENS        Unspecified
# 985           ...                  QUEENS        Unspecified
# 986           ...                  QUEENS        Unspecified
# 987           ...                  QUEENS        Unspecified
# 988           ...                  QUEENS        Unspecified
# 989           ...                  QUEENS        Unspecified
# 990           ...                  QUEENS        Unspecified
# 991           ...                  QUEENS        Unspecified
# 992           ...                  QUEENS        Unspecified
# 993           ...                  QUEENS        Unspecified
# 994           ...                  QUEENS        Unspecified
# 995           ...                  QUEENS        Unspecified
# 996           ...                  QUEENS        Unspecified
# 997           ...                  QUEENS        Unspecified
# 998           ...                  QUEENS        Unspecified
# 999           ...                  QUEENS        Unspecified
#
#     resolution_action_updated_date  \
# 0          2019-05-13T16:32:56.000
# 1          2019-05-13T16:00:12.000
# 2          2019-05-13T16:00:18.000
# 3          2019-05-13T10:28:58.000
# 4          2019-05-13T17:00:39.000
# 5          2019-05-14T00:00:00.000
# 6          2019-05-13T10:28:58.000
# 7          2019-05-10T11:36:00.000
# 8          2019-05-14T00:00:00.000
# 9          2019-05-12T02:05:00.000
# 10         2019-05-09T17:45:00.000
# 11         2019-05-13T14:28:00.000
# 12         2019-05-13T14:31:00.000
# 13         2019-05-13T14:29:00.000
# 14         2019-05-13T14:28:00.000
# 15         2019-05-12T01:30:00.000
# 16         2019-05-14T00:00:00.000
# 17         2019-05-13T10:28:58.000
# 18         2019-05-13T14:30:00.000
# 19         2019-05-13T10:28:58.000
# 20         2019-05-13T10:28:58.000
# 21         2019-05-13T10:28:58.000
# 22         2019-05-13T10:28:58.000
# 23         2019-05-13T10:28:58.000
# 24         2019-05-13T10:28:58.000
# 25         2019-05-13T10:28:58.000
# 26         2019-05-13T10:29:33.000
# 27         2019-05-13T17:40:41.000
# 28         2019-05-13T12:10:02.000
# 29         2019-05-13T09:37:16.000
# ..                             ...
# 970        2013-11-12T14:49:46.000
# 971        2013-10-31T11:39:34.000
# 972        2013-11-06T12:05:40.000
# 973        2013-11-08T12:20:26.000
# 974        2014-05-08T09:41:32.000
# 975        2013-11-06T10:36:41.000
# 976        2013-11-21T14:41:40.000
# 977        2013-11-22T10:12:05.000
# 978        2013-12-05T11:26:19.000
# 979        2017-06-14T15:00:14.000
# 980        2013-12-04T16:48:04.000
# 981        2017-06-19T11:39:28.000
# 982        2013-04-09T15:07:55.000
# 983        2013-12-09T09:33:06.000
# 984        2013-12-09T16:36:39.000
# 985        2014-01-06T09:21:28.000
# 986        2013-12-10T16:48:23.000
# 987        2013-12-18T14:50:41.000
# 988        2014-01-06T12:54:56.000
# 989        2013-12-27T10:47:34.000
# 990        2017-06-13T15:36:20.000
# 991        2013-12-30T12:58:23.000
# 992        2013-12-16T15:47:35.000
# 993        2013-12-18T09:28:04.000
# 994        2013-12-18T16:48:57.000
# 995        2013-12-18T10:30:10.000
# 996        2013-12-24T12:22:31.000
# 997        2014-01-02T17:20:26.000
# 998        2014-01-02T17:49:33.000
# 999        2014-01-02T16:24:53.000
#
#                                 resolution_description    status street_name  \
# 0    The Department of Transportation will inspect ...  Assigned         NaN
# 1    The Department of Parks and Recreation has ins...  Assigned  260 STREET
# 2    The Department of Parks and Recreation visited...    Closed  260 STREET
# 3    The Department of Transportation inspected the...  Assigned         NaN
# 4    The Department of Parks and Recreation inspect...    Closed  267 STREET
# 5                                                  NaN    Closed  267 STREET
# 6    The Department of Transportation inspected the...  Assigned         NaN
# 7    Service Request status for this request is ava...    Closed         NaN
# 8                                                  NaN    Closed   82 AVENUE
# 9    The Department of Environmental Protection inv...    Closed  266 STREET
# 10   The Department of Environmental Protection inv...    Closed  265 STREET
# 11   The Department of Environmental Protection det...    Closed  266 STREET
# 12   The Department of Environmental Protection det...    Closed  268 STREET
# 13   The Department of Environmental Protection det...    Closed   82 AVENUE
# 14   The Department of Environmental Protection det...    Closed  266 STREET
# 15   The Department of Environmental Protection inv...    Closed  264 STREET
# 16                                                 NaN    Closed  267 STREET
# 17   The Department of Transportation inspected the...  Assigned         NaN
# 18   The Department of Environmental Protection det...    Closed  268 STREET
# 19   The Department of Transportation inspected the...  Assigned         NaN
# 20   The Department of Transportation inspected the...  Assigned         NaN
# 21   The Department of Transportation inspected the...  Assigned         NaN
# 22   The Department of Transportation inspected the...  Assigned         NaN
# 23   The Department of Transportation inspected the...  Assigned         NaN
# 24   The Department of Transportation inspected the...  Assigned         NaN
# 25   The Department of Transportation inspected the...  Assigned         NaN
# 26   The Department of Transportation inspected the...  Assigned         NaN
# 27                                          See notes.    Closed         NaN
# 28   The Department of Transportation inspected the...    Closed         NaN
# 29                                          See notes.    Closed         NaN
# ..                                                 ...       ...         ...
# 970                                         See notes.    Closed         NaN
# 971                                         See notes.    Closed         NaN
# 972                                         See notes.    Closed         NaN
# 973                                         See notes.    Closed         NaN
# 974                                         See notes.    Closed         NaN
# 975                                         See notes.    Closed         NaN
# 976                                         See notes.    Closed         NaN
# 977                                         See notes.    Closed         NaN
# 978  The Department of Finance will investigate the...    Closed         NaN
# 979  The Department for the Aging contacted you and...    Closed         NaN
# 980                                         See notes.    Closed         NaN
# 981                                         See notes.    Closed         NaN
# 982  The Department of Finance mailed the requested...    Closed         NaN
# 983  The Department of Finance updated its records ...    Closed         NaN
# 984  The Department for the Aging contacted you and...    Closed         NaN
# 985                                         See notes.    Closed         NaN
# 986                                         See notes.    Closed         NaN
# 987                                         See notes.    Closed         NaN
# 988                                         See notes.    Closed         NaN
# 989     The Department of Finance resolved this issue.    Closed         NaN
# 990                                         See notes.    Closed         NaN
# 991                                         See notes.    Closed         NaN
# 992  The Department of Finance mailed the requested...    Closed         NaN
# 993  The Department of Finance mailed the requested...    Closed         NaN
# 994                                         See notes.    Closed         NaN
# 995  The Department for the Aging contacted you and...    Closed         NaN
# 996                                         See notes.    Closed         NaN
# 997  The Department of Finance was unable to resolv...    Closed         NaN
# 998                                         See notes.    Closed         NaN
# 999                                         See notes.    Closed         NaN
#
#     taxi_pick_up_location unique_key x_coordinate_state_plane  \
# 0                     NaN   42649512                  1064048
# 1                     NaN   42646495                  1064925
# 2                     NaN   42644569                  1064576
# 3                     NaN   42629285                  1061862
# 4                     NaN   42627253                  1065766
# 5                     NaN   42625567                  1066312
# 6                     NaN   42619832                  1061862
# 7                     NaN   42617921                  1063186
# 8                     NaN   42614697                  1066014
# 9                     NaN   42604249                  1066094
# 10                    NaN   42603073                  1065836
# 11                    NaN   42603072                  1066057
# 12                    NaN   42603070                  1066437
# 13                    NaN   42601964                  1066240
# 14                    NaN   42598574                  1066068
# 15                    NaN   42597450                  1065584
# 16                    NaN   42597232                  1066728
# 17                    NaN   42596324                  1061862
# 18                    NaN   42596294                  1066418
# 19                    NaN   42595086                  1061862
# 20                    NaN   42583225                  1061862
# 21                    NaN   42582098                  1061862
# 22                    NaN   42579972                  1061862
# 23                    NaN   42578850                  1061862
# 24                    NaN   42527223                  1061862
# 25                    NaN   42526207                  1061862
# 26                    NaN   42526206                  1061862
# 27                    NaN   42523336                      NaN
# 28                    NaN   42516994                  1061524
# 29                    NaN   42399806                      NaN
# ..                    ...        ...                      ...
# 970                   NaN   26546366                      NaN
# 971                   NaN   26599691                      NaN
# 972                   NaN   26626856                      NaN
# 973                   NaN   26649551                      NaN
# 974                   NaN   27953290                      NaN
# 975                   NaN   26636245                      NaN
# 976                   NaN   26732069                      NaN
# 977                   NaN   26739887                      NaN
# 978                   NaN   26767127                      NaN
# 979                   NaN   36323152                      NaN
# 980                   NaN   26808680                      NaN
# 981                   NaN   36326068                      NaN
# 982                   NaN   26820727                      NaN
# 983                   NaN   26831221                      NaN
# 984                   NaN   26834125                      NaN
# 985                   NaN   26877451                      NaN
# 986                   NaN   26850989                      NaN
# 987                   NaN   26853251                      NaN
# 988                   NaN   26870766                      NaN
# 989                   NaN   26917552                      NaN
# 990                   NaN   36421093                      NaN
# 991                   NaN   26953983                      NaN
# 992                   NaN   26893571                      NaN
# 993                   NaN   26902703                      NaN
# 994                   NaN   26903253                      NaN
# 995                   NaN   26905574                      NaN
# 996                   NaN   26915230                      NaN
# 997                   NaN   27035149                      NaN
# 998                   NaN   26997877                      NaN
# 999                   NaN   27002208                      NaN
#
#     y_coordinate_state_plane
# 0                     210710
# 1                     208582
# 2                     209801
# 3                     212416
# 4                     212363
# 5                     210459
# 6                     212416
# 7                     213310
# 8                     209831
# 9                     210236
# 10                    210212
# 11                    210386
# 12                    210964
# 13                    209895
# 14                    210349
# 15                    210150
# 16                    209007
# 17                    212416
# 18                    211054
# 19                    212416
# 20                    212416
# 21                    212416
# 22                    212416
# 23                    212416
# 24                    212416
# 25                    212416
# 26                    212416
# 27                       NaN
# 28                    213401
# 29                       NaN
# ..                       ...
# 970                      NaN
# 971                      NaN
# 972                      NaN
# 973                      NaN
# 974                      NaN
# 975                      NaN
# 976                      NaN
# 977                      NaN
# 978                      NaN
# 979                      NaN
# 980                      NaN
# 981                      NaN
# 982                      NaN
# 983                      NaN
# 984                      NaN
# 985                      NaN
# 986                      NaN
# 987                      NaN
# 988                      NaN
# 989                      NaN
# 990                      NaN
# 991                      NaN
# 992                      NaN
# 993                      NaN
# 994                      NaN
# 995                      NaN
# 996                      NaN
# 997                      NaN
# 998                      NaN
# 999                      NaN
#
# [1000 rows x 34 columns]

# %% [markdown]
# ### Libraries for company-specific APIs
#
# Google has its own libraries you can import to access their apis. <br>
# NYC also uses the `sodapy` library, Socrata, to manage their open data.

# %% [markdown]
# #### Extra credit for later if you want to play with it

# %%
# Install before running 
# !pip install sodapy

# %% [markdown]
# #### Tokenize yourself, B!
#
# https://dev.socrata.com/foundry/data.cityofnewyork.us/fhrw-4uyv
#
# Scroll down and click to sign up for an app token! This is instantaneous and simple. No credit cards required!

# %%
token = '' 

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", token)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("fhrw-4uyv", incident_zip = '11004', limit=1000)

# %%
type(results)
# Out:
# requests.models.Response

# %%
len(results)

# %%
results[0]

# %%
df_1 = pd.DataFrame(results)

print(len(df_1))
print(df_1.columns)
df_1.head()

# %% [markdown]
# ## Create a Pandas DataFrame of the Data From the Response

# %%
df_2 = pd.DataFrame(data)

print(len(df_2))
print(df_2.columns)
df_2.head()

# %% [markdown]
# ## Create a Histogram of the Complaint Types From Your Dataset

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_2.complaint_type.value_counts().plot(kind='barh', figsize=(8,12))

# %% [markdown]
# ## If we have time:
#
# https://github.com/toddmotto/public-apis
#
#
# find a buddy, find a free api, get the key, and do a get. Try to transform the response into a df.

# %%
#   https://rickandmortyapi.com/
import requests
import pandas as pd
import numpy as np

# %%
url = "https://rickandmortyapi.com/api/character/"

# do the pull
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
else:
    print('Hit an error.')

# %%
data['results'][0]['image']
# Out:
# 'https://rickandmortyapi.com/api/character/avatar/1.jpeg'

# %%
df_rm_pictures = pd.DataFrame()
name_list = []
image_list = []

for i in range(25):
    
    url = "https://rickandmortyapi.com/api/character/?page={}".format(i+1)

    # do the pull
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
    
        for rm_char in data['results']:
            name_list.append(rm_char['name'])
            image_list.append(rm_char['image'])
    
    
    else:
        print('Hit an error.')
    
    


df_rm_pictures['name'] = name_list
df_rm_pictures['image'] = image_list

# %%
type(data)
# Out:
# dict

# %%
df_rm_pictures.head()
# Out:
#            name                                              image
# 0  Rick Sanchez  https://rickandmortyapi.com/api/character/avat...
# 1   Morty Smith  https://rickandmortyapi.com/api/character/avat...
# 2  Summer Smith  https://rickandmortyapi.com/api/character/avat...
# 3    Beth Smith  https://rickandmortyapi.com/api/character/avat...
# 4   Jerry Smith  https://rickandmortyapi.com/api/character/avat...

# %%
from IPython.display import display, Markdown, Latex

# %%
number_image = 1
i = np.random.choice(len(df_rm_pictures), number_image)


for rm_index in i:
    display(Markdown("{0}\n![should be {0}]({1})".format(df_rm_pictures.name[rm_index], df_rm_pictures.image[rm_index])))
# Out:
# Trandor
# ![should be Trandor](https://rickandmortyapi.com/api/character/avatar/363.jpeg)
